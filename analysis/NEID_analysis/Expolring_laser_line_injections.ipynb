# %% [markdown]
# # TITLE HERE

# %% [markdown]
# ### reference material/description:
#
# description:
#
# _Next I want you to create a laser line that we will be injecting into the spectra for testing. This is best done with a Gaussian function with the width of the point-spread function (PSF). Try to create a gaussian function emission line first, and we will inject it into the spectra after that.  Find 5 spectral lines in your spectrum that are very narrow (opposite of the Fraunhofer lines). This PSF width will be used to define our test laser signal._
#
#
# sources/references:
#
# _PSF:_
# <https://en.wikipedia.org/wiki/Point_spread_function>
#
# _gaussians:_ <https://en.wikipedia.org/wiki/Gaussian_function#:~:text=Gaussian%20functions%20are%20widely%20used,and%20to%20define%20the%20Weierstrass>

# %% [markdown]
# ## Point Spread Function (PSF)

# %%
#requires understanding gaussians (distributions)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
#making a gaussian function: 

def gaussian(x,a, b, c):
    '''a is amplitude, b is  the mean (where i think it is), c is standard deviation (sqrt(variance))''' 
    return a*np.e**(-(x-b)**2/(2*c**2))

# %%
x = np.linspace(-10,10,10000)
y = gaussian(x,1,0,3)
plt.plot(x,y)
plt.title('Simple Gaussian')
plt.show()

# %%
#plot in wavelength and plot in velocity and figure out why they're different
