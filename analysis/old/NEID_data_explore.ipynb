# %% [markdown]
# ## Check out the NEID data, specifically the headers.
#  Date: 18 March 2021

# %%
from astropy.io import fits
import numpy as np
from matplotlib import pyplot as plt
from astropy.io.fits import getheader

# %%
data_dir = "/Users/hisaacson/Google Drive/My Drive/KPF/data/neid/"
f_L0 = 'neidL0_20201220T031923.fits' # 334 header entries
f_L1 = 'neidL1_20200225T023236.fits' # 738 header entries
#f_L2 = 'neidL2_20200214T170949.fits' # 738 header entries
f_L2 = "neidL2_20220118T021017.fits" # Newest Tau Ceti file from NEID, 8 feb 2022 added

data_dir2 = "/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI/L2/"
# Owncloud location:
f_L2 = 'neidL2_20210714T063111.fits'
# No.    Name      Ver    Type      Cards   Dimensions   Format
#  0  PRIMARY       1 PrimaryHDU     738   ()      
#  1  SCIFLUX       1 ImageHDU        12   (9216, 117)   float64   
#  2  SKYFLUX       1 ImageHDU        12   (9216, 117)   float64   
#  3  CALFLUX       1 ImageHDU        12   (9216, 117)   float64   
#  4  SCIVAR        1 ImageHDU        12   (9216, 117)   float64   
#  5  SKYVAR        1 ImageHDU        12   (9216, 117)   float64   
#  6  CALVAR        1 ImageHDU        12   (9216, 117)   float64   
#  7  SCIWAVE       1 ImageHDU      1976   (9216, 117)   float64   
#  8  SKYWAVE       1 ImageHDU      1974   ()      
#  9  CALWAVE       1 ImageHDU      1974   ()      

# L1 has same header as L2, but L2 adds four new images: 
# 10  TELLURIC      1 ImageHDU        10   (9216, 117)   float64   
# 11  SKY           1 ImageHDU        10   (9216, 117)   float64   
# 12  CCFS          1 ImageHDU       548   (164, 117)   float64   
# 13  ACTIVITY      1 BinTableHDU     11   0R x 0C   []   

# The difference between the 334 entries in the L0 data and 738 entries in L1/L2 data

# %%
# Open L0 data
print(data_dir+f_L0)
with fits.open(data_dir+f_L0) as hdul0:
    hdul0.info()
    data0 = hdul0['GUIDER'].data
#    data2 = hdul2['SCIFLUX'].data
    head0 = hdul0[0].header
    head1 = hdul0[1].header
    head2 = hdul0[2].header
    
print('HEADER0')    
print(repr(head0)) # prints out header
print('HEADER1')    
print(repr(head1))
print('HEADER2')    
print(repr(head2))#
# data1.info()
# Out:
# /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL0_20201220T031923.fits
# Filename: /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL0_20201220T031923.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     334   ()
#   1  AMPLIFIER 01    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   2  AMPLIFIER 02    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   3  AMPLIFIER 03    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   4  AMPLIFIER 04    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   5  AMPLIFIER 05    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   6  AMPLIFIER 06    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   7  AMPLIFIER 07    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   8  AMPLIFIER 08    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#   9  AMPLIFIER 09    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  10  AMPLIFIER 10    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  11  AMPLIFIER 11    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  12  AMPLIFIER 12    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  13  AMPLIFIER 13    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  14  AMPLIFIER 14    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  15  AMPLIFIER 15    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  16  AMPLIFIER 16    1 ImageHDU        25   (1250, 5000)   int16 (rescales to uint16)
#  17  EXPMETER      1 ImageHDU        75   (256, 6, 69)   float32
#  18  GUIDER        1 ImageHDU       136   (1024, 1024)   int16 (rescales to uint16)
#  19  CFB           1 ImageHDU         8   ()
#  20  SOLAR         1 BinTableHDU     24   0R x 3C   [23A, D, D]
# HEADER0
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T / may the FITS file contain extensions?
# CHECKSUM= 'VgAHVe0EVe7EVe7E'   / HDU checksum updated 2020-12-20T03:20:59
# DATASUM = '0       '           / data unit checksum updated 2020-12-20T03:20:59
# ORIGIN  = 'astropy.io.fits'    / File Originator
# INSTRUME= 'NEID    '           / Instrument Name
# DATALVL =                    0 / Data Product Base Level
# DATATMP =                    F / Data Temporary Intermediate Product
# OBSERVER= 'Valdenebro'         / Observer Name
# TIMESYS = 'UTC     '           / Time Scale
# PROGRAM = '2020B-9999'         / Observing Program ID
# PINAME  = 'Mahadevan'          / Program PI Name
# OBSTYPE = 'Eng     '           / Observation Type
# OBS-MODE= 'HR      '           / Observing Mode
# OBJECT  = 'HD 10700'           / Object Name
# FILENAME= 'neidL0_20201220T031923.fits' / Name of this FITS File
# DATE    = '2020-12-20T03:20:59.842' / File Creation Date (UTC)
# DATE-OBS= '2020-12-20T03:19:23.083' / Obs Date Exp Start (UTC)
# OBSJD   =    2459203.638461609 / Julian Date of DATE-OBS
# EXPTIME =            66.242028 / Exposure Time (s)
# FIBERAPR=                 0.92 / Fiber Aperture Diameter on Sky (arcsec)
# SHUTOPEN= '2020-12-20T03:19:23.083' / Shutter-Open Date (UTC)
# SHUTCLSD= '2020-12-20T03:20:29.325' / Shutter-Close Date (UTC)
# SCI-OBJ = 'Gaia DR2 2452378776434276992' / Object in Science fiber
# CAL-OBJ = 'Dark    '           / Object in Calibration Fiber
# SKY-OBJ = 'Sky     '           / Object in Sky Fiber
# QTIME   = '2020-12-20T01:41:48' / Queue Data Time (UTC)
# QOBJECT = 'Gaia DR2 2452378776434276992' / Queue Object Name
# QRA     = '01:44:02.2'         / Queue Right Ascension
# QDEC    = '-15:56:02'          / Queue Declination
# QEQNX   =               2000.0 / Queue Equinox (yr)
# QEPOCH  =               2000.0 / Queue Epoch (yr)
# QPLX    =             277.5162 / Queue parallax (mas)
# QPMRA   =              -1.7297 / Queue Proper Motion RA ("/yr)
# QPMDEC  =               0.8555 / Queue Proper Motion DEC ("/yr)
# QPROG   = '2020B-9999'         / Queue Program Number
# QRV     =  / Queue RV for Star
# QZ      =  / Queue Z for Star
# QID     =                   99 / Queue ID
# QSNR    =                  0.0 / Queue Signal-to-Noise Ratio
# QEXPTIME=                  0.0 / Queue Exposure Time (s)
# OBSERVAT= 'KPNO    '           / Observatory Name
# TELESCOP= 'WIYN 3.5m'          / Telescope Name
# OBSLON  =          -111.600562 / Observatory Longitude
# OBSLAT  =            31.958092 / Observatory Latitude
# OBSALT  =               2091.0 / Observatory Altitude
# SEEING  =                  0.0 / Seeing at Exp Start (arcsec)
# AIRMASS =               1.4869 / TCS-Telescope Airmass at Exp Start
# FOCUSPOS=               9516.0 / Telescope Focus Pos (mm)
# LIGHTS  =  / Dome Lights
# TCSTIME = '2020-12-20T03:19:27' / TCS-Telescope Data Date (UTC)
# TGTTIME = '2020-12-20T03:19:25' / TCS-Target Data Date (UTC)
# TCSRA   = '+01:44:07.508'      / TCS-Telescope RA J2000
# TCSDEC  = '-15:56:19.964'      / TCS-Telescope DEC J2000
# TCSRAOF = '+00:00:05.308'      / TCS-Telescope RA Offset J2000
# TCSDECOF= '-00:00:17.965'      / TCS-Telescope DEC Offset J2000
# TCSHA   = '0:01:12.36'         / TCS-Telescope Hour Angle (HH:MM:SS)
# TCSLST  = '1:49:43.9726'       / TCS Local Sidereal Time
# TCSZA   =                 90.0 / TCS Zenith Angle
# TCSEL   =              42.2442 / TCS-Target Elevation Angle (deg)
# TCSAZ   =             181.5818 / TCS-Target Azimuth Angle (deg)
# TCSEQNX =               2000.0 / TCS-Target Equinox
# TCSEPOCH=               2000.0 / TCS-Target Epoch
# SUNAGL  =           -35.873107 / Sun Angle (deg)
# MOONUP  =                    T / Moon Above Horizon
# MOONAGL =            72.656854 / Target-Moon Angle (deg)
# ENVTIME = '2020-12-20T03:19:27' / TCS-Weather Data Date (UTC)
# ENVDTMP =                  8.9 / Dome Temperature (C)
# ENVOTMP =                  7.4 / Outside Temperature (C)
# ENVDHUM =                  9.0 / Dome Relative Humidity (%)
# ENVOHUM =                  8.4 / Dome Outside Relative Humidity (%)
# ENVWINDS=                  7.1 / Wind Speed (mph)
# ENVWINDD=                114.5 / Wind Direction (angle)
# DEWPOINT=              -22.371 / Dewpoint Temp (C)
# DOMETIME= '2020-12-20T03:19:27' / TCS-Dome Data Date (UTC)
# DOMETGT =               3.1692 / Dome Commanded Azimuth
# DOMEPOS =               3.1649 / Dome Measured Azimuth
# DOMESTAT= 'closed  '           / Dome Shutter Status
# LS218_1 =               291.55 / Lakeshore 218 HiSkin (K)
# LS218_2 =                291.8 / Lakeshore 218 HiAir (K)
# LS218_3 =               290.06 / Lakeshore 218 LoSkin (K)
# LS218_4 =               290.72 / Lakeshore 218 LoAir (K)
# LS218_5 =               300.82 / Lakeshore 218 Etalon (K)
# LS218_6 =               291.97 / Lakeshore 218 Room (K)
# LS218_7 =               292.59 / Lakeshore 218 CalBench (K)
# LS218_8 =               293.28 / Lakeshore 218 None (K)
# PMKSTOP = 8.20999999999999E-06 / MKS Top Pressure (Torr)
# PMKSBOT =             6.68E-06 / MKS Bottom Pressure (Torr)
# PNEXTORR=              4.3E-06 / NEXTORR Pressure (Torr)
# CCDTEMP =            -99.99978 / Archon CCD Temp (C)
# MOLYTEMP=           -103.83041 / Archon Moly Temp (C)
# SLUGTEMP=           -145.00286 / Archon Slug Temp (C)
# CCDHEAT =    9.515000000000001 / Archon CCD Heat Power (V)
# SLUGHEAT=                3.995 / Archon Slug Heat Power (V)
# FILTER1 =                    4 / Cal Filter Wheel 1
# FILTER2 =  / Cal Filter Wheel 2
# TURRETA =    88.29300000000001 / Cal Turret Pos Angle (deg)
# TURRETS = 'Etalon  '           / Cal Turret Source
# SHUTTER1= 'closed  '           / Cal HR Shutter Status
# SHUTTER2= 'closed  '           / Cal Port Shutter Status
# SHUTTER3= 'open    '           / Exp Meter Shutter Status
# SHUTTER4= 'closed  '           / Solar Feed Shutter Status
# SHUTTER5= 'closed  '           / 2DFlat Feed Shutter Status
# THARM_ST= 'off     '           / Cal ThAr Master Lamp Status
# THARS_ST= 'off     '           / Cal ThAr Slave Lamp Status
# UNEM_ST = 'off     '           / Cal UNe Master Lamp Status
# UNES_ST = 'off     '           / Cal UNe Slave Lamp Status
# THARM_SN= 'P858AHFA0963'       / Cal ThAr Master Lamp Serial Number
# THARS_SN= 'P858AHFA0964'       / Cal ThAr Slave Lamp Serial Number
# UNEM_SN = 'P863HFA0995'        / Cal UNe Master Lamp Serial Number
# UNES_SN = 'P863HFA0991'        / Cal UNe Slave Lamp Serial Number
# THARM_RT= ' 76     '           / ThAr Master Run Time (s)
# THARS_RT= ' 667826+'           / ThAr Slave Run Time (s)
# UNEM_RT = ' 461    '           / UNe Master Run Time (s)
# UNES_RT = ' 400371+'           / UNe Slave Run Time (s)
# ETALO_RT= ' 12120565+'         / Etalon/SuperK Run Time (s)
# LFCPCFSN= 'VIS0002 '           / LFC PCF Serial Number
# LFCPCFRT= ' 1590962+'          / LFC PCF Runtime (s)
# LFCFLIR =               1332.0 / LFC Fiberlock IR Intensity
# LFCFLVIS=                -36.0 / LFC Fiberlock VIS Intensity
# LFCF0   = '4954999997.833'     / LFC Filtered Offset Freq (Hz)
# LFCF0REF= '4955000000.000'     / LFC Filtered Offset Freq Ref (Hz)
# LFCFR   = '20000000000.000'    / LFC Filtered Rep Rate (Hz)
# LFCFRREF= '20000000000.000'    / LFC Filtered Rep Rate Ref (Hz)
# LFCSTAT = '' / LFC Status Bitfield
# TIMSARCN= '20200214'           / TIMS Archon Driver Build
# NAMPS   =                   16 / Number of CCD Amplifiers
# DETSIZE = '[9216,9232]'        / Size of CCD (pixels)
# DETECTOR= 'e2v CCD290-99'      / CCD Model Number
# EXPMFITS= '/tmp/fasttmpfs/AllExpmeterData.fits' / Exp Meter Raw Fits File
# EXP_BIN = '0x0     '           / Exp Meter Binning (pixels)
# EXP_GAIN=                  1.0 / Exp Meter Gain (e-/DN)
# EXP_RN  =                  0.0 / Exp Meter Read Noise
# PTCOVER = 'Open    '           / Port Cover Open
# PTACQFMR= 'Unknown '           / Port Acq Flip Mirror (T=In/F=Out)
# PTACQFOC= '0.000   '           / Port Acq Cam Focus Pos (mm)
# PTACQIMG= '' / Port Acq Cam Last Image
# PTADC1  =                143.5 / Port ADC 1 Position (UNITS?)
# PTADC2  =              -47.497 / Port ADC 2 Position (UNITS?)
# PTADCST = '' / Port ADC Status
# PTCALBM = 'Out     '           / Port Cal Beam Inserter
# PTCALSH = 'Closed  '           / Port Cal Fiber Shutter (T=Open/F=Close)
# PTCALX  =               10.678 / Port Cal Fiber Translator X Pos (mm)
# PTCALY  =                7.744 / Port Cal Fiber Translator Y Pos (mm)
# PTTTMR  =                    0 / Port Tip Tilt Mirror Status
# PTPGI   = 'Open    '           / Port Prism/Grating Inserter
# PTGFIMG = '/home/neid-wnpa/wnpa.data/fits-gf-cam/gf-cam.20201220/gf-cam.202012&'
# CONTINUE  '20.031344.fits&'
# CONTINUE  '' / Port Guide/Focus Camera Last Image
# PTFVCIMG= '' / Port Fiber Viewing Camera Last Image
# PTSCIFBR= 'HR      '           / Port Science Fiber Selector
# PTHESH  = 'Closed  '           / Port HE Shutter
# PTHRSH  = 'Open    '           / Port HR Shutter
# PTCFBFBP= 'V       '           / Port CFB Filter Bandpass
# PTCFBND = 'Open    '           / Port CFB Filter Neutral Density
# PTCFBIMG= '' / Port CFB Last Image
# TMCV2N00=   0.8735563200000001 / TMC 2N2222 Volts - Top-NE Pad
# TMCT2N00=            301.27667 / TMC 2N2222 Temp(K) - Top-NE Pad
# TMCRPT10=         110.96482086 / TMC PT100 Resist(Ohm) - Top-NE Pad
# TMCTPT10=            301.28796 / TMC PT100 Temp(K) - Top-NE Pad
# TMCPHT10=              0.38967 / TMC Heater(W) - Top-NE Pad
# TMCV2N01=           0.87369847 / TMC 2N2222 Volts - Top-NNE Pad
# TMCT2N01=            301.29736 / TMC 2N2222 Temp(K) - Top-NNE Pad
# TMCRPT11=         110.91446686 / TMC PT100 Resist(Ohm) - Top-NNE Pad
# TMCTPT11=            301.33206 / TMC PT100 Temp(K) - Top-NNE Pad
# TMCPHT11=              0.25867 / TMC Heater(W) - Top-NNE Pad
# TMCV2N02=           0.87481183 / TMC 2N2222 Volts - Top-NNW Pad
# TMCT2N02=            301.26981 / TMC 2N2222 Temp(K) - Top-NNW Pad
# TMCRPT12=         110.95258331 / TMC PT100 Resist(Ohm) - Top-NNW Pad
# TMCTPT12=            301.34393 / TMC PT100 Temp(K) - Top-NNW Pad
# TMCPHT12=              0.27277 / TMC Heater(W) - Top-NNW Pad
# TMCV2N03=           0.87498319 / TMC 2N2222 Volts - Top-NW Pad
# TMCT2N03=             301.2796 / TMC 2N2222 Temp(K) - Top-NW Pad
# TMCRPT13=         110.90133667 / TMC PT100 Resist(Ohm) - Top-NW Pad
# TMCTPT13=            301.29208 / TMC PT100 Temp(K) - Top-NW Pad
# TMCPHT13=              0.22387 / TMC Heater(W) - Top-NW Pad
# TMCV2N04=           0.87518775 / TMC 2N2222 Volts - Top-SE Pad
# TMCT2N04=            301.23895 / TMC 2N2222 Temp(K) - Top-SE Pad
# TMCRPT20=         110.97891235 / TMC PT100 Resist(Ohm) - Top-SE Pad
# TMCTPT20=            301.28073 / TMC PT100 Temp(K) - Top-SE Pad
# TMCPHT14=              0.59812 / TMC Heater(W) - Top-SE Pad
# TMCV2N15=           0.87352079 / TMC 2N2222 Volts - Top-SSE Pad
# TMCT2N15=            301.51852 / TMC 2N2222 Temp(K) - Top-SSE Pad
# TMCRPT21=         110.89995575 / TMC PT100 Resist(Ohm) - Top-SSE Pad
# TMCTPT21=            301.26697 / TMC PT100 Temp(K) - Top-SSE Pad
# TMCPHT15=              0.25482 / TMC Heater(W) - Top-SSE Pad
# TMCV2N06=           0.87482452 / TMC 2N2222 Volts - Top-SSW Pad
# TMCT2N06=            301.33517 / TMC 2N2222 Temp(K) - Top-SSW Pad
# TMCRPT22=         110.95062256 / TMC PT100 Resist(Ohm) - Top-SSW Pad
# TMCTPT22=            301.27301 / TMC PT100 Temp(K) - Top-SSW Pad
# TMCPHT16=              0.26092 / TMC Heater(W) - Top-SSW Pad
# TMCV2N07=           0.87412357 / TMC 2N2222 Volts - Top-SW Pad
# TMCT2N07=            301.43512 / TMC 2N2222 Temp(K) - Top-SW Pad
# TMCRPT23=         110.92835999 / TMC PT100 Resist(Ohm) - Top-SW Pad
# TMCTPT23=            301.29514 / TMC PT100 Temp(K) - Top-SW Pad
# TMCPHT17=                0.219 / TMC Heater(W) - Top-SW Pad
# TMCV2N18=           0.87423098 / TMC 2N2222 Volts - Wall-NE Pad
# TMCT2N18=            301.05267 / TMC 2N2222 Temp(K) - Wall-NE Pad
# TMCRPT24=         110.94530487 / TMC PT100 Resist(Ohm) - Wall-NE Pad
# TMCTPT24=            301.31604 / TMC PT100 Temp(K) - Wall-NE Pad
# TMCPHT20=              0.55553 / TMC Heater(W) - Wall-NE Pad
# TMCV2N19=           0.87418014 / TMC 2N2222 Volts - Wall-NNE Pad
# TMCT2N19=            301.45547 / TMC 2N2222 Temp(K) - Wall-NNE Pad
# TMCRPT25=         110.88394928 / TMC PT100 Resist(Ohm) - Wall-NNE Pad
# TMCTPT25=            301.23895 / TMC PT100 Temp(K) - Wall-NNE Pad
# TMCPHT21=              0.25073 / TMC Heater(W) - Wall-NNE Pad
# TMCV2N20=           0.87487322 / TMC 2N2222 Volts - Wall-NNW Pad
# TMCT2N20=            301.22943 / TMC 2N2222 Temp(K) - Wall-NNW Pad
# TMCRPT26=         110.93753052 / TMC PT100 Resist(Ohm) - Wall-NNW Pad
# TMCTPT26=             301.2901 / TMC PT100 Temp(K) - Wall-NNW Pad
# TMCPHT22=              0.26994 / TMC Heater(W) - Wall-NNW Pad
# TMCV2N21=           0.87480199 / TMC 2N2222 Volts - Wall-NW Pad
# TMCT2N21=            301.19489 / TMC 2N2222 Temp(K) - Wall-NW Pad
# TMCRPT27=         110.96429443 / TMC PT100 Resist(Ohm) - Wall-NW Pad
# TMCTPT27=            301.28891 / TMC PT100 Temp(K) - Wall-NW Pad
# TMCPHT23=              0.27355 / TMC Heater(W) - Wall-NW Pad
# TMCV2N22=           0.87360036 / TMC 2N2222 Volts - Face-NW Pad
# TMCT2N22=            301.28357 / TMC 2N2222 Temp(K) - Face-NW Pad
# TMCRPT28=          110.8966217 / TMC PT100 Resist(Ohm) - Face-NW Pad
# TMCTPT28=            301.31995 / TMC PT100 Temp(K) - Face-NW Pad
# TMCPHT24=              0.24469 / TMC Heater(W) - Face-NW Pad
# TMCV2N33=           0.87490183 / TMC 2N2222 Volts - Face-SW Pad
# TMCT2N33=            301.17026 / TMC 2N2222 Temp(K) - Face-SW Pad
# TMCRPT29=         110.92114258 / TMC PT100 Resist(Ohm) - Face-SW Pad
# TMCTPT29=            301.35394 / TMC PT100 Temp(K) - Face-SW Pad
# TMCPHT25=              0.29932 / TMC Heater(W) - Face-SW Pad
# TMCV2N24=           0.87395573 / TMC 2N2222 Volts - Face-NE Pad
# TMCT2N24=            301.40884 / TMC 2N2222 Temp(K) - Face-NE Pad
# TMCRPT14=         110.91132355 / TMC PT100 Resist(Ohm) - Face-NE Pad
# TMCTPT14=            301.36002 / TMC PT100 Temp(K) - Face-NE Pad
# TMCPHT26=              0.61503 / TMC Heater(W) - Face-NE Pad
# TMCV2N25=           0.87421227 / TMC 2N2222 Volts - Face-SE Pad
# TMCT2N25=            301.08224 / TMC 2N2222 Temp(K) - Face-SE Pad
# TMCRPT15=         110.94289398 / TMC PT100 Resist(Ohm) - Face-SE Pad
# TMCTPT15=            301.30405 / TMC PT100 Temp(K) - Face-SE Pad
# TMCPHT27=              0.56921 / TMC Heater(W) - Face-SE Pad
# TMCV2N26=           0.87533784 / TMC 2N2222 Volts - Wall-SE Pad
# TMCT2N26=            301.02219 / TMC 2N2222 Temp(K) - Wall-SE Pad
# TMCRPT16=         110.92124176 / TMC PT100 Resist(Ohm) - Wall-SE Pad
# TMCTPT16=            301.32895 / TMC PT100 Temp(K) - Wall-SE Pad
# TMCPHT30=   0.7252999999999999 / TMC Heater(W) - Wall-SE Pad
# TMCV2N27=            0.8737154 / TMC 2N2222 Volts - Wall-SSE Pad
# TMCT2N27=            301.34949 / TMC 2N2222 Temp(K) - Wall-SSE Pad
# TMCRPT17=         111.07447815 / TMC PT100 Resist(Ohm) - Wall-SSE Pad
# TMCTPT17=            301.31805 / TMC PT100 Temp(K) - Wall-SSE Pad
# TMCPHT31=                0.238 / TMC Heater(W) - Wall-SSE Pad
# TMCV2N28=           0.87504715 / TMC 2N2222 Volts - Wall-SSW Pad
# TMCT2N28=            301.24374 / TMC 2N2222 Temp(K) - Wall-SSW Pad
# TMCRPT18=         110.89691162 / TMC PT100 Resist(Ohm) - Wall-SSW Pad
# TMCTPT18=            301.33099 / TMC PT100 Temp(K) - Wall-SSW Pad
# TMCPHT32=              0.24895 / TMC Heater(W) - Wall-SSW Pad
# TMCV2N34=           0.87494117 / TMC 2N2222 Volts - Wall-SW Pad
# TMCT2N34=            301.16034 / TMC 2N2222 Temp(K) - Wall-SW Pad
# TMCRPT19=         110.96051025 / TMC PT100 Resist(Ohm) - Wall-SW Pad
# TMCTPT19=            301.30707 / TMC PT100 Temp(K) - Wall-SW Pad
# TMCPHT33=              0.28847 / TMC Heater(W) - Wall-SW Pad
# TMCV2N36=   0.8742839100000001 / TMC 2N2222 Volts - Bottom-NE Pad
# TMCT2N36=            301.39844 / TMC 2N2222 Temp(K) - Bottom-NE Pad
# TMCRPT30=         110.94973755 / TMC PT100 Resist(Ohm) - Bottom-NE Pad
# TMCTPT30=            301.29214 / TMC PT100 Temp(K) - Bottom-NE Pad
# TMCPHT34=              0.44847 / TMC Heater(W) - Bottom-NE Pad
# TMCV2N37=   0.8737977099999999 / TMC 2N2222 Volts - Bottom-NNE Pad
# TMCT2N37=            301.37781 / TMC 2N2222 Temp(K) - Bottom-NNE Pad
# TMCRPT31=         110.93928528 / TMC PT100 Resist(Ohm) - Bottom-NNE Pad
# TMCTPT31=            301.28406 / TMC PT100 Temp(K) - Bottom-NNE Pad
# TMCPHT35=              0.22902 / TMC Heater(W) - Bottom-NNE Pad
# TMCV2N38=           0.87481838 / TMC 2N2222 Volts - Bottom-NNW Pad
# TMCT2N38=            301.40451 / TMC 2N2222 Temp(K) - Bottom-NNW Pad
# TMCRPT32=         110.97053528 / TMC PT100 Resist(Ohm) - Bottom-NNW Pad
# TMCTPT32=            301.32501 / TMC PT100 Temp(K) - Bottom-NNW Pad
# TMCPHT36=              0.16672 / TMC Heater(W) - Bottom-NNW Pad
# TMCV2N39=            0.8740027 / TMC 2N2222 Volts - Bottom-NW Pad
# TMCT2N39=            301.40582 / TMC 2N2222 Temp(K) - Bottom-NW Pad
# TMCRPT33=         110.91069031 / TMC PT100 Resist(Ohm) - Bottom-NW Pad
# TMCTPT33=            301.26703 / TMC PT100 Temp(K) - Bottom-NW Pad
# TMCPHT37=              0.32381 / TMC Heater(W) - Bottom-NW Pad
# TMCV2N40=           0.87586683 / TMC 2N2222 Volts - Bottom-SE Pad
# TMCT2N40=            301.32043 / TMC 2N2222 Temp(K) - Bottom-SE Pad
# TMCRPT34=         110.92272186 / TMC PT100 Resist(Ohm) - Bottom-SE Pad
# TMCTPT34=            301.25089 / TMC PT100 Temp(K) - Bottom-SE Pad
# TMCPHT41=              0.32252 / TMC Heater(W) - Bottom-SE Pad
# TMCV2N51=           0.87545043 / TMC 2N2222 Volts - Bottom-SSE Pad
# TMCT2N51=            301.03192 / TMC 2N2222 Temp(K) - Bottom-SSE Pad
# TMCRPT35=         110.93749237 / TMC PT100 Resist(Ohm) - Bottom-SSE Pad
# TMCTPT35=            301.31799 / TMC PT100 Temp(K) - Bottom-SSE Pad
# TMCPHT42=              0.26135 / TMC Heater(W) - Bottom-SSE Pad
# TMCV2N42=           0.87556279 / TMC 2N2222 Volts - Bottom-SSW Pad
# TMCT2N42=            301.03806 / TMC 2N2222 Temp(K) - Bottom-SSW Pad
# TMCRPT36=         110.91983032 / TMC PT100 Resist(Ohm) - Bottom-SSW Pad
# TMCTPT36=            301.29492 / TMC PT100 Temp(K) - Bottom-SSW Pad
# TMCPHT43=              0.27358 / TMC Heater(W) - Bottom-SSW Pad
# TMCV2N43=           0.87335223 / TMC 2N2222 Volts - Bottom-SW Pad
# TMCT2N43=            301.24219 / TMC 2N2222 Temp(K) - Bottom-SW Pad
# TMCRPT37=         110.91139984 / TMC PT100 Resist(Ohm) - Bottom-SW Pad
# TMCTPT37=            301.29501 / TMC PT100 Temp(K) - Bottom-SW Pad
# TMCPHT44=                  0.0 / TMC Heater(W) - Bottom-SW Pad
# TMCV2N30=           1.74828553 / TMC 2N2222 Volts - E LN2 Getter
# TMCT2N30=             80.92735 / TMC 2N2222 Temp(K) - E LN2 Getter
# TMCV2N31=           1.75253654 / TMC 2N2222 Volts - SE LN2 Rail
# TMCT2N31=             79.85535 / TMC 2N2222 Temp(K) - SE LN2 Rail
# TMCV2N08=           0.87960923 / TMC 2N2222 Volts - Bench SW Corner
# TMCT2N08=            299.98318 / TMC 2N2222 Temp(K) - Bench SW Corner
# TMCV2N09=           0.88211751 / TMC 2N2222 Volts - Bench SE Corner
# TMCT2N09=            299.35065 / TMC 2N2222 Temp(K) - Bench SE Corner
# TMCV2N10=           1.58132231 / TMC 2N2222 Volts - Cold Finger TOp
# TMCT2N10=            128.66402 / TMC 2N2222 Temp(K) - Cold Finger TOp
# TMCV2N16=           0.87377614 / TMC 2N2222 Volts - Detector Bot
# TMCT2N16=            301.45413 / TMC 2N2222 Temp(K) - Detector Bot
# TMCV2N12=           0.87298661 / TMC 2N2222 Volts - Detector Top
# TMCT2N12=            301.65323 / TMC 2N2222 Temp(K) - Detector Top
# TMCV2N13=           0.88175726 / TMC 2N2222 Volts - Echelle
# TMCT2N13=             299.4415 / TMC 2N2222 Temp(K) - Echelle
# TMCV2N50=           0.88272512 / TMC 2N2222 Volts - Camera East
# TMCT2N50=            299.19745 / TMC 2N2222 Temp(K) - Camera East
# TMCV2N44=           0.88018817 / TMC 2N2222 Volts - Parabola Top
# TMCT2N44=            299.83719 / TMC 2N2222 Temp(K) - Parabola Top
# TMCV2N45=           0.88070595 / TMC 2N2222 Volts - Parabola Bottom
# TMCT2N45=             299.7066 / TMC 2N2222 Temp(K) - Parabola Bottom
# TMCV2N46=           0.88033545 / TMC 2N2222 Volts - Bench NW Corner
# TMCT2N46=            299.80005 / TMC 2N2222 Temp(K) - Bench NW Corner
# TMCV2N52=           0.88116074 / TMC 2N2222 Volts - Prism Bottom
# TMCT2N52=            299.59192 / TMC 2N2222 Temp(K) - Prism Bottom
# TMCV2N48=           2.16237473 / TMC 2N2222 Volts - Spare
# TMCT2N48=            -23.49435 / TMC 2N2222 Temp(K) - Spare
# TMCV2N49=           0.88235998 / TMC 2N2222 Volts - Camera Prism
# TMCT2N49=            299.28952 / TMC 2N2222 Temp(K) - Camera Prism
# TMCV2N14=           0.88064402 / TMC 2N2222 Volts - Input Optics
# TMCT2N14=            299.72223 / TMC 2N2222 Temp(K) - Input Optics
# TMCV2N32=           0.00021295 / TMC 2N2222 Volts - Short
# TMCT2N32=            521.74231 / TMC 2N2222 Temp(K) - Short
# TMCRPT38=         110.40872192 / TMC PT100 Resist(Ohm) - Mid Bench
# TMCTPT38=            299.99814 / TMC PT100 Temp(K) - Mid Bench
# TMCRPT39=           41.7098732 / TMC PT100 Resist(Ohm) - NW Hanger
# TMCTPT39=            128.21724 / TMC PT100 Temp(K) - NW Hanger
# HEADER1
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1250
# NAXIS2  =                 5000
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# BSCALE  =                    1
# BZERO   =                32768
# BUNIT   = 'DN      '           / Image data units
# AMPNAME = 'Amplifier 01'       / Amplifier name
# AMPNUM  =                    1 / Amplifier number
# AMPROW  =                    0 / Amplifier row
# AMPCOL  =                    0 / Amplifier column
# AMPSEC  = '[1:1250,1:5000]'    / Amplifier section
# DETSEC  = '[1:1152,1:4616]'    / Detector data section
# DATASEC = '[28:1179,1:4616]'   / Image data section
# BIASSEC1= '[1:27,1:5000]'      / Bias section 1
# BIASSEC2= '[28:1179,4617:5000]' / Bias section 2
# BIASSEC3= '[1180:1250,1:5000]' / Bias section 3
# CCDGAIN =                1.656 / Amplifier gain (e-/DN)
# CCDRN   =                 4.28 / Amplifier read noise (e-)
# EXTNAME = 'AMPLIFIER 01'       / Extension name
# CHECKSUM= 'PAA6R094P7A4P774'   / HDU checksum updated 2020-12-20T03:21:00
# DATASUM = '1684137138'         / data unit checksum updated 2020-12-20T03:21:00
# HEADER2
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1250
# NAXIS2  =                 5000
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# BSCALE  =                    1
# BZERO   =                32768
# BUNIT   = 'DN      '           / Image data units
# AMPNAME = 'Amplifier 02'       / Amplifier name
# AMPNUM  =                    2 / Amplifier number
# AMPROW  =                    0 / Amplifier row
# AMPCOL  =                    1 / Amplifier column
# AMPSEC  = '[1:1250,1:5000]'    / Amplifier section
# DETSEC  = '[1153:2304,1:4616]' / Detector data section
# DATASEC = '[28:1179,1:4616]'   / Image data section
# BIASSEC1= '[1:27,1:5000]'      / Bias section 1
# BIASSEC2= '[28:1179,4617:5000]' / Bias section 2
# BIASSEC3= '[1180:1250,1:5000]' / Bias section 3
# CCDGAIN =                1.657 / Amplifier gain (e-/DN)
# CCDRN   =                  4.8 / Amplifier read noise (e-)
# EXTNAME = 'AMPLIFIER 02'       / Extension name
# CHECKSUM= 'ADqODBoNABoNABoN'   / HDU checksum updated 2020-12-20T03:21:00
# DATASUM = '198278077'          / data unit checksum updated 2020-12-20T03:21:00

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
plt.imshow(data0,origin = 'lower',aspect = 'auto',vmin=np.median(data0),interpolation = 'none')

# %%
# L1 data
print(data_dir+f_L1)
with fits.open(data_dir+f_L1) as hdul1:
    data1  = hdul1['SCIFLUX'].data
    head10 = hdul1[0].header
    head3  = hdul1[2].header
    headl1 = hdul1[1].header
    head14 = hdul1[4].header
    data17 = hdul1[7].data
    head17 = hdul1[7].header
    hdul1.info()
    
# print("head1",repr(head11))
# print("head4",repr(head14))
# print("head7",repr(head17))
# data17
print(repr(head3))
# Out:
# /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL1_20200225T023236.fits
# Filename: /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL1_20200225T023236.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     738   ()
#   1  SCIFLUX       1 ImageHDU        12   (9216, 117)   float64
#   2  SKYFLUX       1 ImageHDU        12   (9216, 117)   float64
#   3  CALFLUX       1 ImageHDU        12   (9216, 117)   float64
#   4  SCIVAR        1 ImageHDU        12   (9216, 117)   float64
#   5  SKYVAR        1 ImageHDU        12   (9216, 117)   float64
#   6  CALVAR        1 ImageHDU        12   (9216, 117)   float64
#   7  SCIWAVE       1 ImageHDU      1976   (9216, 117)   float64
#   8  SKYWAVE       1 ImageHDU      1974   ()
#   9  CALWAVE       1 ImageHDU      1974   ()
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 9216
# NAXIS2  =                  117
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SKYFLUX '           / Extension contents
# CTYPE1  = 'X       '           / Name of axis 1
# CTYPE2  = 'Order-50'           / Name of axis 2
# CHECKSUM= '23hA50g020g720g7'   / HDU checksum updated 2020-03-12T03:18:38
# DATASUM = '1635904857'         / data unit checksum updated 2020-03-12T03:18:38

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)
plt.imshow(data1[:,0:],origin = 'lower',aspect = 'auto',vmin=0,interpolation = 'none')

# %%
# Open L2 data.
print(data_dir2+f_L2)
with fits.open(data_dir2+f_L2) as hdul2:
    data2 = hdul2['SCIFLUX'].data
    wave2 = hdul2['SCIWAVE'].data
    head2 = hdul2[7].header
    head28 = hdul2[8].header
    hdul2.info()

# head2
print(repr(head2))
# Out:
# /Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI/L2/neidL2_20210714T063111.fits
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-4d92d89bb082> in <module>
#       1 # Open L2 data.
#       2 print(data_dir2+f_L2)
# ----> 3 with fits.open(data_dir2+f_L2) as hdul2:
#       4     data2 = hdul2['SCIFLUX'].data
#       5     wave2 = hdul2['SCIWAVE'].data
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     174         raise ValueError(f'Empty filename: {name!r}')
#     175
# --> 176     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     177                             lazy_load_hdus, ignore_missing_simple, **kwargs)
#     178
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     409         """
#     410
# --> 411         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                              save_backup=save_backup, cache=cache,
#     413                              ignore_missing_simple=ignore_missing_simple,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1069             if not isinstance(fileobj, _File):
#    1070                 # instantiate a FITS file object (ffo)
# -> 1071                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1072             # The Astropy mode is determined by the _File initializer if the
#    1073             # supplied mode was None
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     545                     warnings.warn(msg, warning_type, stacklevel=2)
#     546
# --> 547             return function(*args, **kwargs)
#     548
#     549         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     388     """
#     389
# --> 390     return open(filename, mode, buffering=0)
#     391
#     392
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI/L2/neidL2_20210714T063111.fits'

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)
plt.imshow(data2[:,0:],origin = 'lower',aspect = 'auto',vmin=0,interpolation = 'none')
#plt.imshow(data1,origin = 'lower',aspect = 'auto',vmin=900,vmax=1.5e3)
#plt.imshow(data2,origin = 'lower',aspect = 'auto',vmin=900,vmax=1.5e3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f5e13c40327c> in <module>
#       2 plt.autoscale(enable=True,axis='both')
#       3 #plt.imshow(data2)
# ----> 4 plt.imshow(data2[:,0:],origin = 'lower',aspect = 'auto',vmin=0,interpolation = 'none')
#       5 #plt.imshow(data1,origin = 'lower',aspect = 'auto',vmin=900,vmax=1.5e3)
#       6 #plt.imshow(data2,origin = 'lower',aspect = 'auto',vmin=900,vmax=1.5e3)
#
# NameError: name 'data2' is not defined

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)

order=80  # Order 80?
plt.scatter(wave2[order,0:9000],data2[order,0:9000],s=1,c='b')
plt.plot('6562.808')

# %%
# Check out the Activity extension and see how the data and header are organized.
with fits.open(data_dir+f_L2) as hdul2:
    data2 = hdul2['SCIFLUX'].data
    head2 = hdul2[0].header
#    hdul2.info()
#    print(repr(head2))

hdul3 = fits.open(data_dir+f_L2)
head = getheader(data_dir+f_L2)
#hdul3.head
bintable_head = hdul3['Activity'].header
bintable_data = hdul3['Activity'].data
#hd23 = hdul3[12].head
#hdul3.columns
#print(repr(bintable_head))
#print(repr(bintable_data))
print(bintable_data.field(0)) # Prints all of the first entries in every row of a FITS_record
print(bintable_data[0])       # Prints the first row in the FITS_record
print(bintable_data.columns)  # Prints column definitions
# Out:
# ['CaIIHK' 'HeI_1' 'HeI_2' 'NaI' 'Ha06_1' 'Ha06_2' 'Ha16_1' 'Ha16_2'
#  'CaI_1' 'CaI_2' 'CaIRT1' 'CaIRT2' 'CaIRT3' 'NaINIR' 'PaDelta']
# ('CaIIHK', 0.13903124743165085, 0.00038854204785905734, '3968.470, 3933.664', 1.09, 3901.07, 4001.07, 20.0, 20.0, '157, 155', '17, 19', '')
# ColDefs(
#     name = 'INDEX'; format = '10A'
#     name = 'VALUE'; format = 'D'
#     name = 'UNCERTAINTY'; format = 'D'
#     name = 'LINE_CENTER'; format = '20A'; unit = 'Ang'
#     name = 'LINE_WIDTH'; format = 'D'; unit = 'Ang'
#     name = 'REF_CENTER1'; format = 'D'; unit = 'Ang'
#     name = 'REF_CENTER2'; format = 'D'; unit = 'Ang'
#     name = 'REF_WIDTH1'; format = 'D'; unit = 'Ang'
#     name = 'REF_WIDTH2'; format = 'D'; unit = 'Ang'
#     name = 'ORDER_USED'; format = '13A'
#     name = 'ORDER_INDEX'; format = '13A'
#     name = 'STATUS'; format = '20A'
# )

# %%
# Open KPF simulated data:
sim_dir = '/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/KPF-Pipeline-TestData/KPF_Simulated_Data/'
sim_sci = 'KPF_simulated_L0_science.fits'

hdu_sim = fits.open(sim_dir+sim_sci)
data1_sim = hdu_sim['GREEN-AMP1'].data
hdu_sim.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-70ad8cd09c7a> in <module>
#       3 sim_sci = 'KPF_simulated_L0_science.fits'
#       4
# ----> 5 hdu_sim = fits.open(sim_dir+sim_sci)
#       6 data1_sim = hdu_sim['GREEN-AMP1'].data
#       7 hdu_sim.info()
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     174         raise ValueError(f'Empty filename: {name!r}')
#     175
# --> 176     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     177                             lazy_load_hdus, ignore_missing_simple, **kwargs)
#     178
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     409         """
#     410
# --> 411         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                              save_backup=save_backup, cache=cache,
#     413                              ignore_missing_simple=ignore_missing_simple,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1069             if not isinstance(fileobj, _File):
#    1070                 # instantiate a FITS file object (ffo)
# -> 1071                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1072             # The Astropy mode is determined by the _File initializer if the
#    1073             # supplied mode was None
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     545                     warnings.warn(msg, warning_type, stacklevel=2)
#     546
# --> 547             return function(*args, **kwargs)
#     548
#     549         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     388     """
#     389
# --> 390     return open(filename, mode, buffering=0)
#     391
#     392
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/KPF-Pipeline-TestData/KPF_Simulated_Data/KPF_simulated_L0_science.fits'

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)
plt.imshow(data1_sim[:,0:],origin = 'lower',aspect = 'auto',vmin=0,interpolation = 'none')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-dc0d5f3db3fe> in <module>
#       2 plt.autoscale(enable=True,axis='both')
#       3 #plt.imshow(data2)
# ----> 4 plt.imshow(data1_sim[:,0:],origin = 'lower',aspect = 'auto',vmin=0,interpolation = 'none')
#
# NameError: name 'data1_sim' is not defined

# %%
#Check out these other files
# Open KPF simulated data:
sim_dir = '/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/KPF-Pipeline-TestData/KPF_Simulated_Data/science/'
#sim_sci = 'kpf_green_L0_20210517T000000.fits'
sim_sci = 'kpf_red_L0_20210525T000000.fits'
hdu_sim = fits.open(sim_dir+sim_sci)
#data1_sim = hdu_sim['GREEN-AMP1'].data
hdu_sim.info()
# Out:
# Filename: /Users/hisaacson/ownCloud/KPF-Pipeline-TestData/KPF-Pipeline-TestData/KPF_Simulated_Data/science/kpf_red_L0_20210525T000000.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  DATA          1 PrimaryHDU       8   (4080, 4080)   float32

# %%
# Plot specific features of L2 data, by listing their name, beg_wavelength and ending wavelength

lines = [
['NaD_I',5888,58992],
['NaD_II',5895,5898],
['H_alpha',6562,6564],    
]

# %%
# Open L2 data.
print(data_dir+f_L2)
with fits.open(data_dir+f_L2) as hdul2:
    data2 = hdul2['SCIFLUX'].data
    wave2 = hdul2['SCIWAVE'].data
    head2 = hdul2[0].header
    head28 = hdul2[8].header
    hdul2.info()
# Out:
# /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL2_20200214T170949.fits
# Filename: /Users/hisaacson/Google Drive/My Drive/KPF/data/neid/neidL2_20200214T170949.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     738   ()
#   1  SCIFLUX       1 ImageHDU        12   (9216, 117)   float64
#   2  SKYFLUX       1 ImageHDU        12   (9216, 117)   float64
#   3  CALFLUX       1 ImageHDU        12   (9216, 117)   float64
#   4  SCIVAR        1 ImageHDU        12   (9216, 117)   float64
#   5  SKYVAR        1 ImageHDU        12   (9216, 117)   float64
#   6  CALVAR        1 ImageHDU        12   (9216, 117)   float64
#   7  SCIWAVE       1 ImageHDU      1976   (9216, 117)   float64
#   8  SKYWAVE       1 ImageHDU      1976   (9216, 117)   float64
#   9  CALWAVE       1 ImageHDU      1976   (9216, 117)   float64
#  10  TELLURIC      1 ImageHDU        10   (9216, 117)   float64
#  11  SKY           1 ImageHDU        10   (9216, 117)   float64
#  12  CCFS          1 ImageHDU       548   (164, 117)   float64
#  13  ACTIVITY      1 BinTableHDU     11   0R x 0C   []

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)

i=0
plt.scatter(wave2,data2,s=1,c='b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2f70f3aa86a3> in <module>
#       4
#       5 i=0
# ----> 6 plt.scatter(wave2,data2,s=1,c='b')
#       7 plt.show()
#
# NameError: name 'wave2' is not defined

# %%
plt.figure(figsize=(20,10))
plt.autoscale(enable=True,axis='both')
#plt.imshow(data2)

i=20
plt.plot(wave2[i,:],data2[i,:])#,c='b-')
plt.ylim(0,5e4)
plt.show()

# %%
data_dir = "/Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI_20191217/L2/"
#f_L0 = 'neidL0_20201220T031923.fits' # 334 header entries
#f_L1 = 'neidL1_20200225T023236.fits' # 738 header entries
f_L2 = 'neidL2_20191217T023129.fits' # 738 header entries

# Open L2 data.
print(data_dir+f_L2)
with fits.open(data_dir+f_L2) as hdul2:
    data2 = hdul2['SCIFLUX'].data
#    head2 = hdul2[0].header
#    head28 = hdul2[8].header
    hdul2.info()
# Out:
# /Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI_20191217/L2/neidL2_20191217T023129.fits
# Filename: /Users/hisaacson/ownCloud/KPF-Pipeline-TestData/NEIDdata/TAUCETI_20191217/L2/neidL2_20191217T023129.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     738   ()
#   1  SCIFLUX       1 ImageHDU        12   (9216, 117)   float64
#   2  SKYFLUX       1 ImageHDU        12   (9216, 117)   float64
#   3  CALFLUX       1 ImageHDU        12   (9216, 117)   float64
#   4  SCIVAR        1 ImageHDU        12   (9216, 117)   float64
#   5  SKYVAR        1 ImageHDU        12   (9216, 117)   float64
#   6  CALVAR        1 ImageHDU        12   (9216, 117)   float64
#   7  SCIWAVE       1 ImageHDU      1976   (9216, 117)   float64
#   8  SKYWAVE       1 ImageHDU      1976   (9216, 117)   float64
#   9  CALWAVE       1 ImageHDU      1976   (9216, 117)   float64
#  10  TELLURIC      1 ImageHDU        10   (9216, 117)   float64
#  11  SKY           1 ImageHDU        10   (9216, 117)   float64
#  12  CCFS          1 ImageHDU       548   (164, 117)   float64
#  13  ACTIVITY      1 BinTableHDU     11   0R x 0C   []
