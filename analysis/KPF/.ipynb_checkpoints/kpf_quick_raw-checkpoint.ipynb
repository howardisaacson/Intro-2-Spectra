# %% [markdown]
# ## First look at raw KPF data. Checking headers
#
#
# 9 Nov 2022
#
# This notebook is ready to examine raw data.

# %%
from astropy.io import fits
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data_dir = "/Users/hisaacson/code/Intro-2-Spectra/data/kpf/"
#fname    = 'KPF_220316_175000.fits' # old data
fname    = 'KP.20230103.71033.03.fits' # 3 jan 2023. raw file
hdu1     = fits.open(data_dir + fname)
raw_g1  = hdu1[1].data 
raw_g2  = hdu1[2].data 
raw_g3  = hdu1[3].data 
raw_g4  = hdu1[4].data 

kpf_hd   = hdu1[1].header # Each data file also has a header.
hdu1.info()
# Out:
# Filename: /Users/hisaacson/code/Intro-2-Spectra/data/kpf/KP.20230103.71033.03.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     307   ()
#   1  GREEN_AMP1    1 ImageHDU        13   (2144, 2140)   float32
#   2  GREEN_AMP2    1 ImageHDU        13   (2144, 2140)   float32
#   3  GREEN_AMP3    1 ImageHDU        13   (2144, 2140)   float32
#   4  GREEN_AMP4    1 ImageHDU        13   (2144, 2140)   float32
#   5  RED_AMP1      1 ImageHDU        13   (2144, 4180)   float32
#   6  RED_AMP2      1 ImageHDU        13   (2144, 4180)   float32
#   7  TELEMETRY     1 BinTableHDU     26   116R x 7C   [35A, 11A, 11A, 8A, 8A, 14A, 67A]

# %%
# Print some summary statistics
# print(len(kpf_raw[0]))
# Out:
# 2144

# %%
print(repr(kpf_hd))
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2144 / length of data axis 1
# NAXIS2  =                 2140 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTNAME = 'GREEN_AMP1'
# HDUVERS =                    1
# AMPSEC  = '[1:2144,1:2140]'    / amplifier section
# GAIN00  =                    1 / gain for AD chan 0
# CCDGAIN =                  5.2 / Current measured amplifier gain in e-/DN Abby S
# OFFSET00=                  100 / offset for AD chan 0

# %%
# Plot up Green CCD.
fig1 = plt.figure(figsize=(20,20))
ax1  = plt.subplot(2,2,1)
ax2  = plt.subplot(2,2,2,sharex=ax1,sharey=ax1)
ax3  = plt.subplot(2,2,3,sharex=ax1,sharey=ax1)
ax4  = plt.subplot(2,2,4,sharex=ax1,sharey=ax1)

plt.rcParams.update({'font.size':15})

ax1.set(title="Green, chip1" ) #xlabel=" Noyes Rotation Period [d]", ylabel="David Rotation Period [d]",       xlim=[0,60], ylim=[0,60]) # Some values of off the right of the plot
ax2.set(title="Green, chip2" )
ax3.set(title="Green, chip3" )
ax4.set(title="Green, chip4" )

#plt.xlabel("Noyes Rotation period[days]")
#plt.ylabel('David Rotation Period [days]')
#plt.ylim([0,50])
#plt.xlim([0,50])


ax1.imshow(raw_g1,vmin = np.median(kpf_raw), vmax = np.median(kpf_raw) * 1.2)#, origin = 'lower')
ax2.imshow(raw_g2,vmin = np.median(kpf_raw), vmax = np.median(kpf_raw) * 1.2)#, origin = 'lower')
ax3.imshow(raw_g3,vmin = np.median(kpf_raw), vmax = np.median(kpf_raw) * 1.2)#, origin = 'lower')
ax4.imshow(raw_g4,vmin = np.median(kpf_raw), vmax = np.median(kpf_raw) * 1.2)#, origin = 'lower')

# %%
# Next show a magnification of one order identifying the sky, science and calibration fibers.
